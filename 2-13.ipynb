# %%
import random

# %%
from random import randint

# %%
from random import randint
print(randint(0, 10))
# Out:
# 4

# %%
from random import randint, choice
print(randint(0, 10))
print(choice(['a', 'b', 'c']))
# Out:
# 6
# b

# %%
from random import *
print(randint(0, 10))
# Out:
# 5

# %%
import random as rd
print(rd.randint(0, 10))
# Out:
# 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-fa18575525b6> in <module>
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
from random import randint as rint
rint(1, 10)
# Out:
# 3

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\FujikawaYuhi\\Documents\\GitHub\\1-2-python-skillup-text-yuhif', 'c:\\Users\\FujikawaYuhi\\.vscode\\extensions\\ms-python.python-2020.8.101144\\pythonFiles\\vscode_datascience_helpers\\..\\.does-not-exist', 'c:\\Users\\FujikawaYuhi\\.vscode\\extensions\\ms-python.python-2020.8.101144\\pythonFiles', 'c:\\Users\\FujikawaYuhi\\.vscode\\extensions\\ms-python.python-2020.8.101144\\pythonFiles\\lib\\python', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32\\python38.zip', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32\\DLLs', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32\\lib', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32', '', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32\\lib\\site-packages', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32\\lib\\site-packages\\win32', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32\\lib\\site-packages\\win32\\lib', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32\\lib\\site-packages\\Pythonwin', 'C:\\Users\\FujikawaYuhi\\AppData\\Local\\Programs\\Python\\Python38-32\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\FujikawaYuhi\\.ipython']

# %%
from math import pow
pow(2,3)
# Out:
# 8.0

# %%
pow(2,3)
# Out:
# 8.0

# %%
pow(2.0, 3)
# Out:
# 8.0

# %%
import random
from random import randint

print(random.randint(0, 10))
print(randint(0, 10))
# Out:
# 2
# 0

# %%
print(random.randint(0, 10))
print(randint(0, 10))
# Out:
# 1
# 10
